# %% [markdown]
# ### Research Question: What is the relationship between internet access benefit uptake and SNAP benefit uptake?

# %% [markdown]
# #### NOTES

# %% [markdown]
# Background from BDT: Lifeline is an older FCC program that helps make communications services more affordable for low-income consumers (source: https://www.fcc.gov/lifeline-consumers). There is a new FCC program called Affordable Connectivity Program (ACP) that helps ensure that households can afford the broadband they need for work, school, healthcare and more that replaced the Emergency Broadband Benefit (EBB) program. (source: https://www.fcc.gov/acp) Given ACP is newer and offers more benefits the priority is to look at ACP benefit enrollment versus SNAP benefit enrollment by geo (i.e. county). This will allow BDT to understand if there are specific regions where ACP enrollment is low relative to SNAP because being enrolled in SNAP is a qualifier for ACP. This comparison will need to use household data for SNAP because ACP is a household benefit.

# %% [markdown]
# Locations of Data: ACP data is available at https://www.usac.org/about/affordable-connectivity-program/acp-enrollment-and-claims-tracker/#enrollment-and-claims-by-zipcode-and-county for 2022 (and there is a data dictionary at https://www.usac.org/wp-content/uploads/about/documents/acp/Data-Dictionary.pdf). SNAP data is located at https://www.fns.usda.gov/pd/supplemental-nutrition-assistance-program-snap.

# %% [markdown]
# Challenge: To understand current gaps it is ideal to look at the most recent data available and the lowest common geo granularity (county). ACP data is available at the county level and has very recent data available for this level- September 2022. SNAP data at the county level has a significant lag- most recent data is July 2021 (over a year older). This presents a gap in this analysis since a household enrolled in SNAP over a year ago may no longer be enrolled in SNAP or may have moved from that county. A comparison is made between the two but it is heavily caveated by the large time difference in the data points which may or may not provide useful directional trends. Also, it is recommended to redo this analysis with newer SNAP data once it is available.

# %% [markdown]
# Geography: BDT currently operates in these 7 states- Colorado, Maryland, Michigan, New York, North Carolina, Pennsylvania, and South Carolina.

# %% [markdown]
# #### Open Questions: 1. Is it beneficial to compare old SNAP data with current ACP data? 2.The SNAP data divides persons and households into Public Assistance Participation and Non Public Assistance Participation. Currently the assumption is to use the combined Public Assistance Participation and Non Public Assistance Participation ("Calc: SNAP Total PA and Non-PA Households") to get the total households using SNAP. Is this valid? 3. There are some counties redacted in ACP data: \**NOT AVAILABLE**. How should this be handled?

# %% [markdown]
# #### DATA LOAD

# %%
#import libraries
import pandas as pd

# %%
#import data
acp=pd.read_excel ('../data-sources/acp/ACP-Households-by-County-January-September-2022.xlsx',dtype={'State FIPS': object}) #acp data
sjul21=pd.read_excel ('../data-sources/snap/Jul-2021.xlsx',skiprows=3, usecols=('Substate/Region','Calc: SNAP Total PA and Non-PA Households')) #July 2021 snap data
sjul20=pd.read_excel ('../data-sources/snap/Jul-2020.xlsx',skiprows=3, usecols=('Substate/Region','Calc: SNAP Total PA and Non-PA Households')) #July 2020 snap data
sjan21=pd.read_excel ('../data-sources/snap/Jan-2021.xls',skiprows=3,usecols=('Substate/Region','Calc: SNAP Total PA and Non-PA Households')) #January 2021 snap data

# %% [markdown]
# #### ACP DATA EXPLORATION

# %%
acp.head()
# Out:
#   Data Month State State Name     County Name State FIPS County FIPS  \
# 0 2022-01-01    AL    ALABAMA  AUTAUGA COUNTY         01         001
# 1 2022-01-01    AL    ALABAMA  BALDWIN COUNTY         01         003
# 2 2022-01-01    AL    ALABAMA  BARBOUR COUNTY         01         005
# 3 2022-01-01    AL    ALABAMA     BIBB COUNTY         01         007
# 4 2022-01-01    AL    ALABAMA   BLOUNT COUNTY         01         009
#
#    Net New Enrollments Alternative Verification Process  \
# 0                                               46.0
# 1                                              -13.0
# 2                                               41.0
# 3                                                0.0
# 4                                               12.0
#
#    Net New Enrollments Verified by School  Net New Enrollments Lifeline  \
# 0                                    -1.0                          20.0
# 1                                     0.0                          78.0
# 2                                     0.0                          56.0
# 3                                     0.0                          14.0
# 4                                    -1.0                          18.0
#
#    Net New Enrollments National Verifier Application  \
# 0                                               53.0
# 1                                              114.0
# 2                                               25.0
# 3                                               23.0
# 4                                               46.0
#
#    Net New Enrollments total  Total Alternative Verification Process  \
# 0                      118.0                                   618.0
# 1                      179.0                                   521.0
# 2                      122.0                                   881.0
# 3                       37.0                                     9.0
# 4                       75.0                                   196.0
#
#    Total Verified by School  Total Lifeline  \
# 0                       2.0           440.0
# 1                       5.0           959.0
# 2                       1.0           444.0
# 3                       5.0           182.0
# 4                      11.0           293.0
#
#    Total National Verifier Application  Total Subscribers
# 0                                874.0             1934.0
# 1                               1281.0             2766.0
# 2                                417.0             1743.0
# 3                                304.0              500.0
# 4                                573.0             1073.0

# %%
acp.tail()
# Out:
#       Data Month State      State Name        County Name State FIPS  \
# 29432 2022-09-01    PR     PUERTO RICO  **NOT AVAILABLE**         72
# 29433 2022-09-01    VI  VIRGIN ISLANDS   ST. CROIX ISLAND         78
# 29434 2022-09-01    VI  VIRGIN ISLANDS    ST. JOHN ISLAND         78
# 29435 2022-09-01    VI  VIRGIN ISLANDS  ST. THOMAS ISLAND         78
# 29436 2022-09-01    VI  VIRGIN ISLANDS  **NOT AVAILABLE**         78
#
#              County FIPS  \
# 29432  **NOT AVAILABLE**
# 29433                010
# 29434                020
# 29435                030
# 29436  **NOT AVAILABLE**
#
#        Net New Enrollments Alternative Verification Process  \
# 29432                                                0.0
# 29433                                                0.0
# 29434                                                0.0
# 29435                                                0.0
# 29436                                                0.0
#
#        Net New Enrollments Verified by School  Net New Enrollments Lifeline  \
# 29432                                     0.0                          55.0
# 29433                                     0.0                           2.0
# 29434                                     0.0                           0.0
# 29435                                     0.0                          -1.0
# 29436                                     0.0                           0.0
#
#        Net New Enrollments National Verifier Application  \
# 29432                                               24.0
# 29433                                              305.0
# 29434                                                2.0
# 29435                                              139.0
# 29436                                                2.0
#
#        Net New Enrollments total  Total Alternative Verification Process  \
# 29432                       79.0                                     0.0
# 29433                      307.0                                     0.0
# 29434                        2.0                                     0.0
# 29435                      138.0                                     0.0
# 29436                        2.0                                     0.0
#
#        Total Verified by School  Total Lifeline  \
# 29432                       0.0           142.0
# 29433                       1.0           105.0
# 29434                       0.0             0.0
# 29435                       0.0            81.0
# 29436                       0.0             0.0
#
#        Total National Verifier Application  Total Subscribers
# 29432                                115.0              257.0
# 29433                               1596.0             1702.0
# 29434                                 22.0               22.0
# 29435                               1112.0             1193.0
# 29436                                  3.0                3.0

# %%
acp.dtypes
# Out:
# Data Month                                              datetime64[ns]
# State                                                           object
# State Name                                                      object
# County Name                                                     object
# State FIPS                                                      object
# County FIPS                                                     object
# Net New Enrollments Alternative Verification Process           float64
# Net New Enrollments Verified by School                         float64
# Net New Enrollments Lifeline                                   float64
# Net New Enrollments National Verifier Application              float64
# Net New Enrollments total                                      float64
# Total Alternative Verification Process                         float64
# Total Verified by School                                       float64
# Total Lifeline                                                 float64
# Total National Verifier Application                            float64
# Total Subscribers                                              float64
# dtype: object

# %%
acp.describe(include='all')
# Out:
#                  Data Month  State State Name        County Name State FIPS  \
# count                 29437  29437      29437              29437      29437
# unique                    9     56         56               1967         56
# top     2022-07-01 00:00:00     TX      TEXAS  **NOT AVAILABLE**         48
# freq                   3280   2290       2290                483       2290
# first   2022-01-01 00:00:00    NaN        NaN                NaN        NaN
# last    2022-09-01 00:00:00    NaN        NaN                NaN        NaN
# mean                    NaN    NaN        NaN                NaN        NaN
# std                     NaN    NaN        NaN                NaN        NaN
# min                     NaN    NaN        NaN                NaN        NaN
# 25%                     NaN    NaN        NaN                NaN        NaN
# 50%                     NaN    NaN        NaN                NaN        NaN
# 75%                     NaN    NaN        NaN                NaN        NaN
# max                     NaN    NaN        NaN                NaN        NaN
#
#               County FIPS  \
# count               29437
# unique                331
# top     **NOT AVAILABLE**
# freq                  483
# first                 NaN
# last                  NaN
# mean                  NaN
# std                   NaN
# min                   NaN
# 25%                   NaN
# 50%                   NaN
# 75%                   NaN
# max                   NaN
#
#         Net New Enrollments Alternative Verification Process  \
# count                                        29435.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                            58.882691
# std                                            361.515105
# min                                          -1533.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                             23.000000
# max                                          20481.000000
#
#         Net New Enrollments Verified by School  Net New Enrollments Lifeline  \
# count                             29435.000000                  29435.000000
# unique                                     NaN                           NaN
# top                                        NaN                           NaN
# freq                                       NaN                           NaN
# first                                      NaN                           NaN
# last                                       NaN                           NaN
# mean                                 -0.027824                     16.534058
# std                                   0.846077                    318.228748
# min                                 -24.000000                 -27109.000000
# 25%                                   0.000000                     -4.000000
# 50%                                   0.000000                      2.000000
# 75%                                   0.000000                     19.000000
# max                                  45.000000                   7861.000000
#
#         Net New Enrollments National Verifier Application  \
# count                                        29435.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                            96.451299
# std                                            421.212930
# min                                          -3366.000000
# 25%                                              4.000000
# 50%                                             18.000000
# 75%                                             61.000000
# max                                          20929.000000
#
#         Net New Enrollments total  Total Alternative Verification Process  \
# count                29435.000000                            29435.000000
# unique                        NaN                                     NaN
# top                           NaN                                     NaN
# freq                          NaN                                     NaN
# first                         NaN                                     NaN
# last                          NaN                                     NaN
# mean                   171.840224                              893.840156
# std                    741.299169                             4182.876818
# min                  -7237.000000                                0.000000
# 25%                      6.000000                                1.000000
# 50%                     33.000000                               25.000000
# 75%                    121.000000                              462.000000
# max                  42768.000000                           214701.000000
#
#         Total Verified by School  Total Lifeline  \
# count               29435.000000    29435.000000
# unique                       NaN             NaN
# top                          NaN             NaN
# freq                         NaN             NaN
# first                        NaN             NaN
# last                         NaN             NaN
# mean                    2.115713     1517.046781
# std                    12.370113     5781.753065
# min                     0.000000        0.000000
# 25%                     0.000000       87.500000
# 50%                     0.000000      337.000000
# 75%                     1.000000     1015.000000
# max                   352.000000   195775.000000
#
#         Total National Verifier Application  Total Subscribers
# count                          29435.000000       29435.000000
# unique                                  NaN                NaN
# top                                     NaN                NaN
# freq                                    NaN                NaN
# first                                   NaN                NaN
# last                                    NaN                NaN
# mean                            1265.441345        3678.443995
# std                             5029.129687       13950.190310
# min                                0.000000           0.000000
# 25%                               85.000000         222.000000
# 50%                              289.000000         817.000000
# 75%                              858.000000        2555.500000
# max                           211815.000000      574801.000000

# %% [markdown]
# #### ACP DATA CLEANUP

# %%
#concatenate State and Country FIPS
acp['FIPS'] = acp['State FIPS'].astype(str) + acp['County FIPS'].astype(str)

# %%
acp.head()
# Out:
#   Data Month State State Name     County Name State FIPS County FIPS  \
# 0 2022-01-01    AL    ALABAMA  AUTAUGA COUNTY         01         001
# 1 2022-01-01    AL    ALABAMA  BALDWIN COUNTY         01         003
# 2 2022-01-01    AL    ALABAMA  BARBOUR COUNTY         01         005
# 3 2022-01-01    AL    ALABAMA     BIBB COUNTY         01         007
# 4 2022-01-01    AL    ALABAMA   BLOUNT COUNTY         01         009
#
#    Net New Enrollments Alternative Verification Process  \
# 0                                               46.0
# 1                                              -13.0
# 2                                               41.0
# 3                                                0.0
# 4                                               12.0
#
#    Net New Enrollments Verified by School  Net New Enrollments Lifeline  \
# 0                                    -1.0                          20.0
# 1                                     0.0                          78.0
# 2                                     0.0                          56.0
# 3                                     0.0                          14.0
# 4                                    -1.0                          18.0
#
#    Net New Enrollments National Verifier Application  \
# 0                                               53.0
# 1                                              114.0
# 2                                               25.0
# 3                                               23.0
# 4                                               46.0
#
#    Net New Enrollments total  Total Alternative Verification Process  \
# 0                      118.0                                   618.0
# 1                      179.0                                   521.0
# 2                      122.0                                   881.0
# 3                       37.0                                     9.0
# 4                       75.0                                   196.0
#
#    Total Verified by School  Total Lifeline  \
# 0                       2.0           440.0
# 1                       5.0           959.0
# 2                       1.0           444.0
# 3                       5.0           182.0
# 4                      11.0           293.0
#
#    Total National Verifier Application  Total Subscribers   FIPS
# 0                                874.0             1934.0  01001
# 1                               1281.0             2766.0  01003
# 2                                417.0             1743.0  01005
# 3                                304.0              500.0  01007
# 4                                573.0             1073.0  01009

# %%
#reduce columns
acp = acp[['Data Month', 'State Name','County Name','FIPS','Total Subscribers']].copy()

# %%
#check for null
acp.isnull().values.any()
# Out:
# True

# %%
#inspect null
acp[acp['Total Subscribers'].isnull()]
# Out:
#       Data Month            State Name        County Name  \
# 23209 2022-08-01  DISTRICT OF COLUMBIA  **NOT AVAILABLE**
# 26489 2022-09-01  DISTRICT OF COLUMBIA  **NOT AVAILABLE**
#
#                       FIPS  Total Subscribers
# 23209  11**NOT AVAILABLE**                NaN
# 26489  11**NOT AVAILABLE**                NaN

# %%
#fill NaN
acp['Total Subscribers'] = acp['Total Subscribers'].fillna(0)

# %%
#convert subscribers to integer
acp['Total Subscribers'] = acp['Total Subscribers'].astype(int)

# %%
acp.dtypes
# Out:
# Data Month           datetime64[ns]
# State Name                   object
# County Name                  object
# FIPS                         object
# Total Subscribers             int32
# dtype: object

# %%
#extract latest acp data (September 2022)
asep22 = acp[acp['Data Month']=='2022-09-01 00:00:00']

# %%
#inspect rows with County Name **NOT AVAILABLE** 
asep22[asep22['County Name']=='**NOT AVAILABLE**']
# Out:
#       Data Month                State Name        County Name  \
# 26225 2022-09-01                   ALABAMA  **NOT AVAILABLE**
# 26258 2022-09-01                    ALASKA  **NOT AVAILABLE**
# 26274 2022-09-01                   ARIZONA  **NOT AVAILABLE**
# 26350 2022-09-01                  ARKANSAS  **NOT AVAILABLE**
# 26409 2022-09-01                CALIFORNIA  **NOT AVAILABLE**
# 26474 2022-09-01                  COLORADO  **NOT AVAILABLE**
# 26483 2022-09-01               CONNECTICUT  **NOT AVAILABLE**
# 26487 2022-09-01                  DELAWARE  **NOT AVAILABLE**
# 26489 2022-09-01      DISTRICT OF COLUMBIA  **NOT AVAILABLE**
# 26557 2022-09-01                   FLORIDA  **NOT AVAILABLE**
# 26717 2022-09-01                   GEORGIA  **NOT AVAILABLE**
# 26766 2022-09-01                     IDAHO  **NOT AVAILABLE**
# 26869 2022-09-01                  ILLINOIS  **NOT AVAILABLE**
# 26962 2022-09-01                   INDIANA  **NOT AVAILABLE**
# 27062 2022-09-01                      IOWA  **NOT AVAILABLE**
# 27168 2022-09-01                    KANSAS  **NOT AVAILABLE**
# 27289 2022-09-01                  KENTUCKY  **NOT AVAILABLE**
# 27354 2022-09-01                 LOUISIANA  **NOT AVAILABLE**
# 27371 2022-09-01                     MAINE  **NOT AVAILABLE**
# 27396 2022-09-01                  MARYLAND  **NOT AVAILABLE**
# 27411 2022-09-01             MASSACHUSETTS  **NOT AVAILABLE**
# 27495 2022-09-01                  MICHIGAN  **NOT AVAILABLE**
# 27583 2022-09-01                 MINNESOTA  **NOT AVAILABLE**
# 27666 2022-09-01               MISSISSIPPI  **NOT AVAILABLE**
# 27782 2022-09-01                  MISSOURI  **NOT AVAILABLE**
# 27839 2022-09-01                   MONTANA  **NOT AVAILABLE**
# 27927 2022-09-01                  NEBRASKA  **NOT AVAILABLE**
# 27945 2022-09-01                    NEVADA  **NOT AVAILABLE**
# 27956 2022-09-01             NEW HAMPSHIRE  **NOT AVAILABLE**
# 27978 2022-09-01                NEW JERSEY  **NOT AVAILABLE**
# 28012 2022-09-01                NEW MEXICO  **NOT AVAILABLE**
# 28075 2022-09-01                  NEW YORK  **NOT AVAILABLE**
# 28176 2022-09-01            NORTH CAROLINA  **NOT AVAILABLE**
# 28229 2022-09-01              NORTH DAKOTA  **NOT AVAILABLE**
# 28318 2022-09-01                      OHIO  **NOT AVAILABLE**
# 28396 2022-09-01                  OKLAHOMA  **NOT AVAILABLE**
# 28433 2022-09-01                    OREGON  **NOT AVAILABLE**
# 28501 2022-09-01              PENNSYLVANIA  **NOT AVAILABLE**
# 28507 2022-09-01              RHODE ISLAND  **NOT AVAILABLE**
# 28554 2022-09-01            SOUTH CAROLINA  **NOT AVAILABLE**
# 28622 2022-09-01              SOUTH DAKOTA  **NOT AVAILABLE**
# 28718 2022-09-01                 TENNESSEE  **NOT AVAILABLE**
# 28973 2022-09-01                     TEXAS  **NOT AVAILABLE**
# 29003 2022-09-01                      UTAH  **NOT AVAILABLE**
# 29151 2022-09-01                  VIRGINIA  **NOT AVAILABLE**
# 29191 2022-09-01                WASHINGTON  **NOT AVAILABLE**
# 29247 2022-09-01             WEST VIRGINIA  **NOT AVAILABLE**
# 29320 2022-09-01                 WISCONSIN  **NOT AVAILABLE**
# 29344 2022-09-01                   WYOMING  **NOT AVAILABLE**
# 29348 2022-09-01            AMERICAN SAMOA  **NOT AVAILABLE**
# 29353 2022-09-01  NORTHERN MARIANA ISLANDS  **NOT AVAILABLE**
# 29432 2022-09-01               PUERTO RICO  **NOT AVAILABLE**
# 29436 2022-09-01            VIRGIN ISLANDS  **NOT AVAILABLE**
#
#                       FIPS  Total Subscribers
# 26225  01**NOT AVAILABLE**                 32
# 26258  02**NOT AVAILABLE**                  2
# 26274  04**NOT AVAILABLE**                152
# 26350  05**NOT AVAILABLE**                 25
# 26409  06**NOT AVAILABLE**                 21
# 26474  08**NOT AVAILABLE**                 25
# 26483  09**NOT AVAILABLE**                  6
# 26487  10**NOT AVAILABLE**                  2
# 26489  11**NOT AVAILABLE**                  0
# 26557  12**NOT AVAILABLE**                 24
# 26717  13**NOT AVAILABLE**                 52
# 26766  16**NOT AVAILABLE**                  7
# 26869  17**NOT AVAILABLE**                 54
# 26962  18**NOT AVAILABLE**                 28
# 27062  19**NOT AVAILABLE**                  5
# 27168  20**NOT AVAILABLE**                  6
# 27289  21**NOT AVAILABLE**                 48
# 27354  22**NOT AVAILABLE**                 38
# 27371  23**NOT AVAILABLE**                  2
# 27396  24**NOT AVAILABLE**                 10
# 27411  25**NOT AVAILABLE**                 15
# 27495  26**NOT AVAILABLE**                 21
# 27583  27**NOT AVAILABLE**                 20
# 27666  28**NOT AVAILABLE**                 28
# 27782  29**NOT AVAILABLE**                 32
# 27839  30**NOT AVAILABLE**                  5
# 27927  31**NOT AVAILABLE**                  3
# 27945  32**NOT AVAILABLE**                  3
# 27956  33**NOT AVAILABLE**                  1
# 27978  34**NOT AVAILABLE**                 12
# 28012  35**NOT AVAILABLE**                109
# 28075  36**NOT AVAILABLE**                 34
# 28176  37**NOT AVAILABLE**                 35
# 28229  38**NOT AVAILABLE**                  2
# 28318  39**NOT AVAILABLE**                 40
# 28396  40**NOT AVAILABLE**                 44
# 28433  41**NOT AVAILABLE**                  6
# 28501  42**NOT AVAILABLE**                 26
# 28507  44**NOT AVAILABLE**                  5
# 28554  45**NOT AVAILABLE**                 10
# 28622  46**NOT AVAILABLE**                  7
# 28718  47**NOT AVAILABLE**                 45
# 28973  48**NOT AVAILABLE**                 73
# 29003  49**NOT AVAILABLE**                 10
# 29151  51**NOT AVAILABLE**                 29
# 29191  53**NOT AVAILABLE**                  8
# 29247  54**NOT AVAILABLE**                 17
# 29320  55**NOT AVAILABLE**                 11
# 29344  56**NOT AVAILABLE**                  2
# 29348  60**NOT AVAILABLE**                  1
# 29353  69**NOT AVAILABLE**                  1
# 29432  72**NOT AVAILABLE**                257
# 29436  78**NOT AVAILABLE**                  3

# %%
asep22[asep22['County Name']=='**NOT AVAILABLE**']['State Name'].unique()
# Out:
# array(['ALABAMA', 'ALASKA', 'ARIZONA', 'ARKANSAS', 'CALIFORNIA',
#        'COLORADO', 'CONNECTICUT', 'DELAWARE', 'DISTRICT OF COLUMBIA',
#        'FLORIDA', 'GEORGIA', 'IDAHO', 'ILLINOIS', 'INDIANA', 'IOWA',
#        'KANSAS', 'KENTUCKY', 'LOUISIANA', 'MAINE', 'MARYLAND',
#        'MASSACHUSETTS', 'MICHIGAN', 'MINNESOTA', 'MISSISSIPPI',
#        'MISSOURI', 'MONTANA', 'NEBRASKA', 'NEVADA', 'NEW HAMPSHIRE',
#        'NEW JERSEY', 'NEW MEXICO', 'NEW YORK', 'NORTH CAROLINA',
#        'NORTH DAKOTA', 'OHIO', 'OKLAHOMA', 'OREGON', 'PENNSYLVANIA',
#        'RHODE ISLAND', 'SOUTH CAROLINA', 'SOUTH DAKOTA', 'TENNESSEE',
#        'TEXAS', 'UTAH', 'VIRGINIA', 'WASHINGTON', 'WEST VIRGINIA',
#        'WISCONSIN', 'WYOMING', 'AMERICAN SAMOA',
#        'NORTHERN MARIANA ISLANDS', 'PUERTO RICO', 'VIRGIN ISLANDS'],
#       dtype=object)

# %%
asep22.head()
# Out:
#       Data Month State Name     County Name   FIPS  Total Subscribers
# 26158 2022-09-01    ALABAMA  AUTAUGA COUNTY  01001               2944
# 26159 2022-09-01    ALABAMA  BALDWIN COUNTY  01003               3603
# 26160 2022-09-01    ALABAMA  BARBOUR COUNTY  01005               2764
# 26161 2022-09-01    ALABAMA     BIBB COUNTY  01007                697
# 26162 2022-09-01    ALABAMA   BLOUNT COUNTY  01009               1799

# %%
asep22.dtypes
# Out:
# Data Month           datetime64[ns]
# State Name                   object
# County Name                  object
# FIPS                         object
# Total Subscribers             int32
# FIPS Code                    object
# dtype: object

# %%
asep22.describe(include='all')
# Out:
#                  Data Month State Name        County Name   FIPS  \
# count                  3279       3279               3279   3279
# unique                    1         56               1963   3279
# top     2022-09-01 00:00:00      TEXAS  **NOT AVAILABLE**  01089
# freq                   3279        255                 53      1
# first   2022-09-01 00:00:00        NaN                NaN    NaN
# last    2022-09-01 00:00:00        NaN                NaN    NaN
# mean                    NaN        NaN                NaN    NaN
# std                     NaN        NaN                NaN    NaN
# min                     NaN        NaN                NaN    NaN
# 25%                     NaN        NaN                NaN    NaN
# 50%                     NaN        NaN                NaN    NaN
# 75%                     NaN        NaN                NaN    NaN
# max                     NaN        NaN                NaN    NaN
#
#         Total Subscribers FIPS Code
# count         3279.000000      3279
# unique                NaN      3279
# top                   NaN     01089
# freq                  NaN         1
# first                 NaN       NaN
# last                  NaN       NaN
# mean          4301.413236       NaN
# std          16051.487507       NaN
# min              0.000000       NaN
# 25%            260.000000       NaN
# 50%            979.000000       NaN
# 75%           3017.000000       NaN
# max         574801.000000       NaN

# %% [markdown]
# #### SNAP DATA EXPLORATION

# %%
sjul21.head()
# Out:
#                     Substate/Region  JUL21 SNAP Households FIPS Code
# 0  0100101 AL EBT AUTAUGA CO FS OFF                   3522     01001
# 1  0100301 AL EBT BALDWIN CO FS OFF                   9311     01003
# 2  0100501 AL EBT BARBOUR CO FS OFF                   2778     01005
# 3     0100701 AL EBT BIBB CO FS OFF                   1696     01007
# 4   0100901 AL EBT BLOUNT CO FS OFF                   2911     01009

# %%
sjul21.tail()
# Out:
#                      Substate/Region Calc: SNAP Total PA and Non-PA Households
# 2641  5600002 WY EBT WYOMING SD PASS                                     13496
# 2642                    U.S. Summary                                  22344689
# 2643                             NaN                                       NaN
# 2644                             NaN                                       NaN
# 2645                             NaN                                       NaN

# %% [markdown]
# #### SNAP DATA CLEANUP

# %%
#remove summary line
sjul21=sjul21[sjul21['Substate/Region'] != 'U.S. Summary']

# %%
#remove empty rows
sjul21=sjul21.dropna(how='all')

# %%
sjul21.tail()
# Out:
#                             Substate/Region  \
# 2637  5514901 WI EBT BAD RIVER TRIBAL COUNC
# 2638  5515101 WI EBT LAC DU FLAMBEAU TRIBAL
# 2639  5515301 WI EBT SOKAOGON TRIBAL AGENCY
# 2640        5515501 WI EBT POTAWATOMI TRIBE
# 2641         5600002 WY EBT WYOMING SD PASS
#
#      Calc: SNAP Total PA and Non-PA Households
# 2637                                       185
# 2638                                       555
# 2639                                       102
# 2640                                        18
# 2641                                     13496

# %%
#extract FIPS code
sjul21['FIPS Code']=sjul21['Substate/Region'].str[:5]

# %%
sjul21.tail()
# Out:
#                             Substate/Region  \
# 2637  5514901 WI EBT BAD RIVER TRIBAL COUNC
# 2638  5515101 WI EBT LAC DU FLAMBEAU TRIBAL
# 2639  5515301 WI EBT SOKAOGON TRIBAL AGENCY
# 2640        5515501 WI EBT POTAWATOMI TRIBE
# 2641         5600002 WY EBT WYOMING SD PASS
#
#      Calc: SNAP Total PA and Non-PA Households FIPS Code
# 2637                                       185     55149
# 2638                                       555     55151
# 2639                                       102     55153
# 2640                                        18     55155
# 2641                                     13496     56000

# %%
sjul21.dtypes
# Out:
# Substate/Region                              object
# Calc: SNAP Total PA and Non-PA Households    object
# FIPS Code                                    object
# dtype: object

# %%
# find blank values
sjul21[sjul21['Calc: SNAP Total PA and Non-PA Households']=="  "]
# Out:
#                           Substate/Region  \
# 159  0515992 AR EBT 92-1 Field Operations
# 160  0515996 AR EBT 96-1 Field Operations
#
#     Calc: SNAP Total PA and Non-PA Households FIPS Code
# 159                                               05159
# 160                                               05159

# %%
#fill blank values
sjul21['Calc: SNAP Total PA and Non-PA Households'][sjul21['Calc: SNAP Total PA and Non-PA Households']=="  "]=0

# %%
sjul21['Calc: SNAP Total PA and Non-PA Households'] = pd.to_numeric(sjul21['Calc: SNAP Total PA and Non-PA Households'])

# %%
sjul21.dtypes
# Out:
# Substate/Region                              object
# Calc: SNAP Total PA and Non-PA Households     int64
# FIPS Code                                    object
# dtype: object

# %%
sjul21 = sjul21.rename(columns={'Calc: SNAP Total PA and Non-PA Households': 'JUL21 SNAP Households'})

# %%
sjul21.head()
# Out:
#                     Substate/Region  JUL21 SNAP Households FIPS Code
# 0  0100101 AL EBT AUTAUGA CO FS OFF                   3522     01001
# 1  0100301 AL EBT BALDWIN CO FS OFF                   9311     01003
# 2  0100501 AL EBT BARBOUR CO FS OFF                   2778     01005
# 3     0100701 AL EBT BIBB CO FS OFF                   1696     01007
# 4   0100901 AL EBT BLOUNT CO FS OFF                   2911     01009

# %%
sjul21['FIPS Code'] = sjul21['FIPS Code'].astype(str)

# %%
sjul21.dtypes
# Out:
# Substate/Region          object
# JUL21 SNAP Households     int64
# FIPS Code                object
# dtype: object

# %%
sjul21.describe(include='all')
# Out:
#                      Substate/Region  JUL21 SNAP Households FIPS Code
# count                           2642           2.642000e+03      2642
# unique                          2642                    NaN      2549
# top     4003301 OK EBT COTTON COUNTY                    NaN     17031
# freq                               1                    NaN        33
# mean                             NaN           8.457490e+03       NaN
# std                              NaN           4.654792e+04       NaN
# min                              NaN           0.000000e+00       NaN
# 25%                              NaN           6.560000e+02       NaN
# 50%                              NaN           1.712500e+03       NaN
# 75%                              NaN           4.479750e+03       NaN
# max                              NaN           1.608545e+06       NaN

# %%
sjul21[sjul21.duplicated(['FIPS Code'], keep=False)]
# Out:
#                                       Substate/Region  JUL21 SNAP Households  \
# 4                     0100901 AL EBT BLOUNT CO FS OFF                   2911
# 5          0100999 AL EBT AESAP - Alabama Dept. of HR                      0
# 159              0515992 AR EBT 92-1 Field Operations                      0
# 160              0515996 AR EBT 96-1 Field Operations                      0
# 531                           1703100 IL EBT ILLINOIS                      0
# ...                                               ...                    ...
# 2367  4992509 UT SSI Utah Dept. of Workforce Services                   1380
# 2368                 5000004 VT EBT VT DPT OF SOC WEL                  23065
# 2369                 5000004 VT SSI VT DPT OF SOC WEL                  15322
# 2375                  5101308 VA EBT ARLINGTON CO DPW                   4335
# 2376                         5101312 VA EBT Alleghany                   1031
#
#      FIPS Code
# 4        01009
# 5        01009
# 159      05159
# 160      05159
# 531      17031
# ...        ...
# 2367     49925
# 2368     50000
# 2369     50000
# 2375     51013
# 2376     51013
#
# [152 rows x 3 columns]

# %% [markdown]
# #### JOIN ACP & SNAP DATA

# %%
df = pd.merge(sjul21,asep22, how='full outer join', on=['FIPS Code','FIPS'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-245-68b6d8529f63> in <module>
# ----> 1 df = pd.merge(sjul21,asep22, how='full outer join', on=['FIPS Code','FIPS'])
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
#     629         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     994                         right_keys.append(rk)
#     995                     if lk is not None:
# --> 996                         left_keys.append(left._get_label_or_level_values(lk))
#     997                         join_names.append(lk)
#     998                     else:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'FIPS Code'

# %%
#sjul20.head()

# %%
#sjan21.head()
