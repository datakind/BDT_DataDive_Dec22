# %% [markdown]
# ### Research Question: What is the relationship between internet access benefit uptake and SNAP benefit uptake?

# %% [markdown]
# #### NOTES

# %% [markdown]
# Background from BDT: Lifeline is an older FCC program that helps make communications services more affordable for low-income consumers (source: https://www.fcc.gov/lifeline-consumers). There is a new FCC program called Affordable Connectivity Program (ACP) that helps ensure that households can afford the broadband they need for work, school, healthcare and more that replaced the Emergency Broadband Benefit (EBB) program. (source: https://www.fcc.gov/acp) Given ACP is newer and offers more benefits the priority is to look at ACP benefit enrollment versus SNAP benefit enrollment by geo (i.e. county). This will allow BDT to understand if there are specific regions where ACP enrollment is low relative to SNAP because being enrolled in SNAP is a qualifier for ACP. This comparison will need to use household data for SNAP because ACP is a household benefit.

# %% [markdown]
# Locations of Data: ACP data is available at https://www.usac.org/about/affordable-connectivity-program/acp-enrollment-and-claims-tracker/#enrollment-and-claims-by-zipcode-and-county for 2022 (and there is a data dictionary at https://www.usac.org/wp-content/uploads/about/documents/acp/Data-Dictionary.pdf). SNAP data is located at https://www.fns.usda.gov/pd/supplemental-nutrition-assistance-program-snap.

# %% [markdown]
# Challenge: To understand current gaps it is ideal to look at the most recent data available and the lowest common geo granularity (county). ACP data is available at the county level and has very recent data available for this level- September 2022. SNAP data at the county level has a significant lag- most recent data is July 2021 (over a year older). This presents a gap in this analysis since a household enrolled in SNAP over a year ago may no longer be enrolled in SNAP or may have moved from that county. A comparison is made between the two but it is heavily caveated by the large time difference in the data points which may or may not provide useful directional trends. Also, it is recommended to redo this analysis with newer SNAP data once it is available.

# %% [markdown]
# Geography: BDT currently operates in these 7 states- Colorado, Maryland, Michigan, New York, North Carolina, Pennsylvania, and South Carolina.

# %% [markdown]
# Open Questions: The SNAP data divides persons and households into Public Assistance Participation and Non Public Assistance Participation. Currently the assumption is to use the combined Public Assistance Participation and Non Public Assistance Participation ("Calc: SNAP Total PA and Non-PA Households") to get the total households using SNAP. Is this valid?

# %% [markdown]
# #### DATA LOAD

# %%
#import libraries
import pandas as pd

# %%
#import data
acp=pd.read_excel ('../data-sources/acp/ACP-Households-by-County-January-September-2022.xlsx') #acp data
sjul21=pd.read_excel ('../data-sources/snap/Jul-2021.xlsx',skiprows=3, usecols=('Substate/Region','Calc: SNAP Total PA and Non-PA Households')) #July 2021 snap data
sjul20=pd.read_excel ('../data-sources/snap/Jul-2020.xlsx',skiprows=3, usecols=('Substate/Region','Calc: SNAP Total PA and Non-PA Households')) #July 2020 snap data
sjan21=pd.read_excel ('../data-sources/snap/Jan-2021.xls',skiprows=3,usecols=('Substate/Region','Calc: SNAP Total PA and Non-PA Households')) #January 2021 snap data

# %% [markdown]
# #### DATA EXPLORATION

# %%
acp.head()
# Out:
#   Data Month State State Name     County Name  State FIPS County FIPS  \
# 0 2022-01-01    AL    ALABAMA  AUTAUGA COUNTY           1         001
# 1 2022-01-01    AL    ALABAMA  BALDWIN COUNTY           1         003
# 2 2022-01-01    AL    ALABAMA  BARBOUR COUNTY           1         005
# 3 2022-01-01    AL    ALABAMA     BIBB COUNTY           1         007
# 4 2022-01-01    AL    ALABAMA   BLOUNT COUNTY           1         009
#
#    Net New Enrollments Alternative Verification Process  \
# 0                                               46.0
# 1                                              -13.0
# 2                                               41.0
# 3                                                0.0
# 4                                               12.0
#
#    Net New Enrollments Verified by School  Net New Enrollments Lifeline  \
# 0                                    -1.0                          20.0
# 1                                     0.0                          78.0
# 2                                     0.0                          56.0
# 3                                     0.0                          14.0
# 4                                    -1.0                          18.0
#
#    Net New Enrollments National Verifier Application  \
# 0                                               53.0
# 1                                              114.0
# 2                                               25.0
# 3                                               23.0
# 4                                               46.0
#
#    Net New Enrollments total  Total Alternative Verification Process  \
# 0                      118.0                                   618.0
# 1                      179.0                                   521.0
# 2                      122.0                                   881.0
# 3                       37.0                                     9.0
# 4                       75.0                                   196.0
#
#    Total Verified by School  Total Lifeline  \
# 0                       2.0           440.0
# 1                       5.0           959.0
# 2                       1.0           444.0
# 3                       5.0           182.0
# 4                      11.0           293.0
#
#    Total National Verifier Application  Total Subscribers
# 0                                874.0             1934.0
# 1                               1281.0             2766.0
# 2                                417.0             1743.0
# 3                                304.0              500.0
# 4                                573.0             1073.0

# %%
acp.describe(include='all')
# Out:
#                  Data Month  State State Name        County Name  \
# count                 29437  29437      29437              29437
# unique                    9     56         56               1967
# top     2022-07-01 00:00:00     TX      TEXAS  **NOT AVAILABLE**
# freq                   3280   2290       2290                483
# first   2022-01-01 00:00:00    NaN        NaN                NaN
# last    2022-09-01 00:00:00    NaN        NaN                NaN
# mean                    NaN    NaN        NaN                NaN
# std                     NaN    NaN        NaN                NaN
# min                     NaN    NaN        NaN                NaN
# 25%                     NaN    NaN        NaN                NaN
# 50%                     NaN    NaN        NaN                NaN
# 75%                     NaN    NaN        NaN                NaN
# max                     NaN    NaN        NaN                NaN
#
#           State FIPS        County FIPS  \
# count   29437.000000              29437
# unique           NaN                331
# top              NaN  **NOT AVAILABLE**
# freq             NaN                483
# first            NaN                NaN
# last             NaN                NaN
# mean       31.400890                NaN
# std        16.442176                NaN
# min         1.000000                NaN
# 25%        19.000000                NaN
# 50%        30.000000                NaN
# 75%        46.000000                NaN
# max        78.000000                NaN
#
#         Net New Enrollments Alternative Verification Process  \
# count                                        29435.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                            58.882691
# std                                            361.515105
# min                                          -1533.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                             23.000000
# max                                          20481.000000
#
#         Net New Enrollments Verified by School  Net New Enrollments Lifeline  \
# count                             29435.000000                  29435.000000
# unique                                     NaN                           NaN
# top                                        NaN                           NaN
# freq                                       NaN                           NaN
# first                                      NaN                           NaN
# last                                       NaN                           NaN
# mean                                 -0.027824                     16.534058
# std                                   0.846077                    318.228748
# min                                 -24.000000                 -27109.000000
# 25%                                   0.000000                     -4.000000
# 50%                                   0.000000                      2.000000
# 75%                                   0.000000                     19.000000
# max                                  45.000000                   7861.000000
#
#         Net New Enrollments National Verifier Application  \
# count                                        29435.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                            96.451299
# std                                            421.212930
# min                                          -3366.000000
# 25%                                              4.000000
# 50%                                             18.000000
# 75%                                             61.000000
# max                                          20929.000000
#
#         Net New Enrollments total  Total Alternative Verification Process  \
# count                29435.000000                            29435.000000
# unique                        NaN                                     NaN
# top                           NaN                                     NaN
# freq                          NaN                                     NaN
# first                         NaN                                     NaN
# last                          NaN                                     NaN
# mean                   171.840224                              893.840156
# std                    741.299169                             4182.876818
# min                  -7237.000000                                0.000000
# 25%                      6.000000                                1.000000
# 50%                     33.000000                               25.000000
# 75%                    121.000000                              462.000000
# max                  42768.000000                           214701.000000
#
#         Total Verified by School  Total Lifeline  \
# count               29435.000000    29435.000000
# unique                       NaN             NaN
# top                          NaN             NaN
# freq                         NaN             NaN
# first                        NaN             NaN
# last                         NaN             NaN
# mean                    2.115713     1517.046781
# std                    12.370113     5781.753065
# min                     0.000000        0.000000
# 25%                     0.000000       87.500000
# 50%                     0.000000      337.000000
# 75%                     1.000000     1015.000000
# max                   352.000000   195775.000000
#
#         Total National Verifier Application  Total Subscribers
# count                          29435.000000       29435.000000
# unique                                  NaN                NaN
# top                                     NaN                NaN
# freq                                    NaN                NaN
# first                                   NaN                NaN
# last                                    NaN                NaN
# mean                            1265.441345        3678.443995
# std                             5029.129687       13950.190310
# min                                0.000000           0.000000
# 25%                               85.000000         222.000000
# 50%                              289.000000         817.000000
# 75%                              858.000000        2555.500000
# max                           211815.000000      574801.000000

# %%
#extract latest acp data (September 2022)
aSep22 = acp[acp['Data Month']=='2022-09-01 00:00:00']

# %%
aSep22.describe(include='all')
# Out:
#                  Data Month State State Name        County Name   State FIPS  \
# count                  3279  3279       3279               3279  3279.000000
# unique                    1    56         56               1963          NaN
# top     2022-09-01 00:00:00    TX      TEXAS  **NOT AVAILABLE**          NaN
# freq                   3279   255        255                 53          NaN
# first   2022-09-01 00:00:00   NaN        NaN                NaN          NaN
# last    2022-09-01 00:00:00   NaN        NaN                NaN          NaN
# mean                    NaN   NaN        NaN                NaN    31.395852
# std                     NaN   NaN        NaN                NaN    16.459670
# min                     NaN   NaN        NaN                NaN     1.000000
# 25%                     NaN   NaN        NaN                NaN    19.000000
# 50%                     NaN   NaN        NaN                NaN    30.000000
# 75%                     NaN   NaN        NaN                NaN    46.000000
# max                     NaN   NaN        NaN                NaN    78.000000
#
#               County FIPS  \
# count                3279
# unique                331
# top     **NOT AVAILABLE**
# freq                   53
# first                 NaN
# last                  NaN
# mean                  NaN
# std                   NaN
# min                   NaN
# 25%                   NaN
# 50%                   NaN
# 75%                   NaN
# max                   NaN
#
#         Net New Enrollments Alternative Verification Process  \
# count                                         3278.000000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                            59.123551
# std                                            367.287648
# min                                           -741.000000
# 25%                                              0.000000
# 50%                                              0.000000
# 75%                                             19.000000
# max                                          15690.000000
#
#         Net New Enrollments Verified by School  Net New Enrollments Lifeline  \
# count                              3278.000000                   3278.000000
# unique                                     NaN                           NaN
# top                                        NaN                           NaN
# freq                                       NaN                           NaN
# first                                      NaN                           NaN
# last                                       NaN                           NaN
# mean                                 -0.034472                     17.890177
# std                                   0.704210                    126.170093
# min                                 -24.000000                  -2002.000000
# 25%                                   0.000000                     -3.000000
# 50%                                   0.000000                      2.000000
# 75%                                   0.000000                     13.000000
# max                                   5.000000                   3152.000000
#
#         Net New Enrollments National Verifier Application  \
# count                                          3278.00000
# unique                                                NaN
# top                                                   NaN
# freq                                                  NaN
# first                                                 NaN
# last                                                  NaN
# mean                                            102.85540
# std                                             382.13547
# min                                            -222.00000
# 25%                                               4.00000
# 50%                                              19.00000
# 75%                                              68.00000
# max                                            8568.00000
#
#         Net New Enrollments total  Total Alternative Verification Process  \
# count                 3278.000000                             3278.000000
# unique                        NaN                                     NaN
# top                           NaN                                     NaN
# freq                          NaN                                     NaN
# first                         NaN                                     NaN
# last                          NaN                                     NaN
# mean                   179.834655                             1134.332520
# std                    693.683249                             5532.031873
# min                   -375.000000                                0.000000
# 25%                      8.000000                                1.000000
# 50%                     35.000000                               21.000000
# 75%                    128.000000                              570.500000
# max                  25463.000000                           214701.000000
#
#         Total Verified by School  Total Lifeline  \
# count                3278.000000     3278.000000
# unique                       NaN             NaN
# top                          NaN             NaN
# freq                         NaN             NaN
# first                        NaN             NaN
# last                         NaN             NaN
# mean                    1.890177     1495.912447
# std                    12.799628     5469.331561
# min                     0.000000        0.000000
# 25%                     0.000000       86.000000
# 50%                     0.000000      345.500000
# 75%                     1.000000     1023.000000
# max                   328.000000   148277.000000
#
#         Total National Verifier Application  Total Subscribers
# count                           3278.000000        3278.000000
# unique                                  NaN                NaN
# top                                     NaN                NaN
# freq                                    NaN                NaN
# first                                   NaN                NaN
# last                                    NaN                NaN
# mean                            1670.590299        4302.725442
# std                             6347.155592       16053.760532
# min                                0.000000           1.000000
# 25%                              119.000000         260.000000
# 50%                              398.000000         980.000000
# 75%                             1144.750000        3018.000000
# max                           211815.000000      574801.000000

# %%
#trim acp
aSep22['State Name'].unique()
# Out:
# array(['ALABAMA', 'ALASKA', 'ARIZONA', 'ARKANSAS', 'CALIFORNIA',
#        'COLORADO', 'CONNECTICUT', 'DELAWARE', 'DISTRICT OF COLUMBIA',
#        'FLORIDA', 'GEORGIA', 'HAWAII', 'IDAHO', 'ILLINOIS', 'INDIANA',
#        'IOWA', 'KANSAS', 'KENTUCKY', 'LOUISIANA', 'MAINE', 'MARYLAND',
#        'MASSACHUSETTS', 'MICHIGAN', 'MINNESOTA', 'MISSISSIPPI',
#        'MISSOURI', 'MONTANA', 'NEBRASKA', 'NEVADA', 'NEW HAMPSHIRE',
#        'NEW JERSEY', 'NEW MEXICO', 'NEW YORK', 'NORTH CAROLINA',
#        'NORTH DAKOTA', 'OHIO', 'OKLAHOMA', 'OREGON', 'PENNSYLVANIA',
#        'RHODE ISLAND', 'SOUTH CAROLINA', 'SOUTH DAKOTA', 'TENNESSEE',
#        'TEXAS', 'UTAH', 'VERMONT', 'VIRGINIA', 'WASHINGTON',
#        'WEST VIRGINIA', 'WISCONSIN', 'WYOMING', 'AMERICAN SAMOA', 'GUAM',
#        'NORTHERN MARIANA ISLANDS', 'PUERTO RICO', 'VIRGIN ISLANDS'],
#       dtype=object)

# %%
acp[acp['County Name']=='**NOT AVAILABLE**']['State Name'].unique()
# Out:
# array(['ALABAMA', 'ALASKA', 'AMERICAN SAMOA', 'ARIZONA', 'ARKANSAS',
#        'CALIFORNIA', 'COLORADO', 'CONNECTICUT', 'DELAWARE', 'FLORIDA',
#        'GEORGIA', 'HAWAII', 'IDAHO', 'ILLINOIS', 'INDIANA', 'IOWA',
#        'KANSAS', 'KENTUCKY', 'LOUISIANA', 'MAINE', 'MARYLAND',
#        'MASSACHUSETTS', 'MICHIGAN', 'MINNESOTA', 'MISSISSIPPI',
#        'MISSOURI', 'MONTANA', 'NEBRASKA', 'NEVADA', 'NEW HAMPSHIRE',
#        'NEW JERSEY', 'NEW MEXICO', 'NEW YORK', 'NORTH CAROLINA',
#        'NORTH DAKOTA', 'NORTHERN MARIANA ISLANDS', 'OHIO', 'OKLAHOMA',
#        'OREGON', 'PENNSYLVANIA', 'PUERTO RICO', 'RHODE ISLAND',
#        'SOUTH CAROLINA', 'SOUTH DAKOTA', 'TENNESSEE', 'TEXAS', 'UTAH',
#        'VERMONT', 'VIRGINIA', 'WASHINGTON', 'WEST VIRGINIA', 'WISCONSIN',
#        'WYOMING', 'VIRGIN ISLANDS', 'DISTRICT OF COLUMBIA'], dtype=object)

# %%
sjul21.head()
# Out:
#                     Substate/Region Calc: SNAP Total PA and Non-PA Households
# 0  0100101 AL EBT AUTAUGA CO FS OFF                                      3522
# 1  0100301 AL EBT BALDWIN CO FS OFF                                      9311
# 2  0100501 AL EBT BARBOUR CO FS OFF                                      2778
# 3     0100701 AL EBT BIBB CO FS OFF                                      1696
# 4   0100901 AL EBT BLOUNT CO FS OFF                                      2911

# %%
sjul21['Substate/Region'].str[:5]
# Out:
# 0       01001
# 1       01003
# 2       01005
# 3       01007
# 4       01009
#         ...
# 2641    56000
# 2642    U.S.
# 2643      NaN
# 2644      NaN
# 2645      NaN
# Name: Substate/Region, Length: 2646, dtype: object

# %%
sjul21.tail()
# Out:
#                      Substate/Region Calc: SNAP Total PA and Non-PA Households
# 2641  5600002 WY EBT WYOMING SD PASS                                     13496
# 2642                    U.S. Summary                                  22344689
# 2643                             NaN                                       NaN
# 2644                             NaN                                       NaN
# 2645                             NaN                                       NaN

# %%
sjul21.dtypes
# Out:
# Substate/Region                              object
# Calc: SNAP Total PA and Non-PA Households    object
# Code                                         object
# State                                        object
# EBT                                          object
# County                                       object
# Designation                                  object
# 6                                            object
# 7                                            object
# 8                                            object
# 9                                            object
# dtype: object

# %%
sjul21['Substate/Region'].str.split(' ', expand=True)
# Out:
#             0        1     2        3     4     5     6     7     8
# 0     0100101       AL   EBT  AUTAUGA    CO    FS   OFF  None  None
# 1     0100301       AL   EBT  BALDWIN    CO    FS   OFF  None  None
# 2     0100501       AL   EBT  BARBOUR    CO    FS   OFF  None  None
# 3     0100701       AL   EBT     BIBB    CO    FS   OFF  None  None
# 4     0100901       AL   EBT   BLOUNT    CO    FS   OFF  None  None
# ...       ...      ...   ...      ...   ...   ...   ...   ...   ...
# 2641  5600002       WY   EBT  WYOMING    SD  PASS  None  None  None
# 2642     U.S.  Summary  None     None  None  None  None  None  None
# 2643      NaN      NaN   NaN      NaN   NaN   NaN   NaN   NaN   NaN
# 2644      NaN      NaN   NaN      NaN   NaN   NaN   NaN   NaN   NaN
# 2645      NaN      NaN   NaN      NaN   NaN   NaN   NaN   NaN   NaN
#
# [2646 rows x 9 columns]

# %%
sjul21[['Code','State','EBT','County','Designation','6','7','8','9']] = sjul21['Substate/Region'].str.split(' ', expand=True)

#sjul21[['V','allele']] = df['V'].str.split('-',expand=True)

# %%
sjul21.describe()
# Out:
#                      Substate/Region  \
# count                           2643
# unique                          2643
# top     4003301 OK EBT COTTON COUNTY
# freq                               1
#
#         Calc: SNAP Total PA and Non-PA Households     Code State   EBT County  \
# count                                        2643     2643  2643  2642   2642
# unique                                       2077     2590    54     3   1521
# top                                             0  4100005    TX   EBT   COOK
# freq                                          101        3   254  2588     30
#
#        Designation     6    7     8   9
# count         2015  1444  403    93  12
# unique         185   126   79    45  11
# top             CO   DSS  OFF  CSHR  UN
# freq          1140   329   58    25   2

# %%
sjul21['EBT'].unique()
# Out:
# array(['EBT', 'SSI', 'WRI', None, nan], dtype=object)

# %%
sjul21['Designation'].unique()
# Out:
# array(['CO', '-', 'CO.', 'CLAIR', None, 'CRUZ', 'PAZ', 'COUNTY', 'SPRING',
#        'RIVER', 'FRANCIS', 'BUREN', 'Field', 'COSTA', 'NORTE', 'DORADO',
#        'ANGELES', 'BENITO', 'BRNDINO', 'DIEGO', 'FRANCISCO', 'JOAQUIN',
#        'LUIS', 'MATEO', 'BARBARA', 'CLARA', 'CREEK', 'PASO', 'HINSDALE',
#        'CARSON', 'PLATA', 'ANIMAS', 'BLANCO', 'GRANDE', 'JUAN', 'MIGUEL',
#        'OF', 'CASTLE', 'Treasury', 'BEACH', 'JOHNS', 'LUCIE', 'ROSA',
#        'HILL', 'KALB', 'DAVIS', '', 'STATE', 'FIELD', 'Illinois', 'SOUTH',
#        'KIDS', 'DAVIESS', 'ISLAND', 'CALL', 'PORTE', 'JOSEPH', 'HAWK',
#        'VISTA', 'GORDO', 'MOINES', 'BRIEN', 'ALTO', 'County', 'PARISH',
#        'SOTO', 'BATON', 'CARROLL', 'FELICIANA', 'SALLE', 'COUPEE',
#        'BERNARD', 'CHARLES', 'HELENA', 'JAMES', 'JOHN', 'LANDRY',
#        'MARTIN', 'MARY', 'TAMMANY', 'DEPT', 'ARUNDEL', 'GEORGES', 'ANNES',
#        'MARYS', 'CITY', 'TRAVERSE', '(INGHAM', 'ISLE', 'COFIN', 'SOCIAL',
#        'STONE', 'EARTH', 'DODGE', 'WING', 'FAM', 'QUI', 'LACS', 'TAIL',
#        'LAKE', 'LOUIS', 'Prairie', 'MEDICINE', 'Earth', 'Lake', 'Dept.',
#        'AURMORED', 'STAMP', 'PINE', 'HEALTH', 'MAY', 'BACA', 'ANA',
#        'ALAMOS', 'ARRIBA', 'FE', 'YORK', 'HANOVER', 'VAL', 'FORKS', 'Co',
#        'WORLD-DELAWARE', 'WORLD', 'INC.', 'WORLD-ROSS', 'WERT', 'FLORE',
#        'MILLS', '&', 'HUMAN', 'HOMME', 'BUFF', 'MIX', 'F', 'COOK',
#        'PHERSON', 'FD', 'SMITH', 'WITT', 'BEND', 'HOGG', 'WELLS', 'OAK',
#        'PINTO', 'AUGUSTINE', 'JACINTO', 'PATRICIO', 'SABA', 'GREEN',
#        'VERDE', 'ZANDT', 'DPT', 'BRUNSWICK', 'DSS', 'HT', 'EMPORIA',
#        'AND', 'GEORGE', 'WILLIAM', 'LANCASTER', 'MIDDLESEX', 'KENT',
#        'EDWARD', 'AREA', 'SSD', 'D', 'SOC', 'POQUOSON', 'City', 'Vista',
#        'Heights', 'Church', 'DPW', 'MANASSAS', 'NEWS', 'BUR', 'DHS',
#        'CLAIRE', 'DU', 'CROSSE', 'CROIX', 'TRIBAL', 'TRI', 'CLIFF',
#        'TRIBE', 'SD', nan], dtype=object)

# %%
#sjul20.head()

# %%
#sjan21.head()
